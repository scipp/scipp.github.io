# %%
import numpy as np
import scipp as sc

# %% [markdown]
# # How to...
# ## Create variables
# ### Scalar variable using operators with units

# %%
1.2 * sc.units.kg
# Out:
#     <scipp.Variable>          float64    [kg]             ()  [1.200000]

# %% [markdown]
# ### Scalar variable from Python object

# %%
sc.Variable(1.2)
# Out:
#     <scipp.Variable>          float64    [dimensionless]  ()  [1.200000]

# %%
sc.Variable("string")
# Out:
#     <scipp.Variable>          string     [dimensionless]  ()  ["string"]

# %%
sc.Variable([1,2,3])
# Out:
#     <scipp.Variable>          PyObject   [dimensionless]  ()  [PyObject]

# %% [markdown]
# ### Initialized with default values

# %%
sc.Variable(['y', 'x'], shape=(2,3))
# Out:
#     <scipp.Variable>          float64    [dimensionless]  (y, x)  [0.000000, 0.000000, ..., 0.000000, 0.000000]

# %% [markdown]
# ### From Python list or NumPy array

# %%
sc.Variable(['x'], values=[1.2, 2.3])
# Out:
#     <scipp.Variable>          float64    [dimensionless]  (x)  [1.200000, 2.300000]

# %%
sc.Variable(['y', 'x'], values=np.array([[1, 2], [3, 4]]))
# Out:
#     <scipp.Variable>          int64      [dimensionless]  (y, x)  [1, 2, 3, 4]

# %% [markdown]
# ## Create an empty dataset

# %%
d = sc.Dataset()
d
# Out:
# <scipp.Dataset>
# Dimensions: {}

# %% [markdown]
# ## Add / insert a data item, a coord, labels, a mask, or an attr

# %%
var = sc.Variable(['x'], shape=(2,))

# %%
d['data'] = var
d.coords['x'] = var
d.coords['lab'] = var
d.masks['mask'] = sc.Variable(['x'], shape=(2,), dtype=sc.dtype.bool)
d.attrs['info'] = sc.Variable("text")
d
# Out:
# <scipp.Dataset>
# Dimensions: {{x, 2}}
# Coordinates:
#     x                         float64    [dimensionless]  (x)  [0.000000, 0.000000]
#     lab                       float64    [dimensionless]  (x)  [0.000000, 0.000000]
# Attributes:
#     info                      string     [dimensionless]  ()  ["text"]
# Masks:
#     mask                      bool       [dimensionless]  (x)  [False, False]
# Data:
#     data                      float64    [dimensionless]  (x)  [0.000000, 0.000000]

# %% [markdown]
# ## Get a data item, a coord, labels, a mask, or an attr

# %%
d['data']
# Out:
# <scipp.DataArrayView>
# Dimensions: {{x, 2}}
# Coordinates:
#     x                         float64    [dimensionless]  (x)  [0.000000, 0.000000]
#     lab                       float64    [dimensionless]  (x)  [0.000000, 0.000000]
# Masks:
#     mask                      bool       [dimensionless]  (x)  [False, False]
# Data:
#     data                      float64    [dimensionless]  (x)  [0.000000, 0.000000]

# %%
d.coords['x']
# Out:
#     <scipp.VariableView>      float64    [dimensionless]  (x)  [0.000000, 0.000000]

# %%
d.coords['lab']
# Out:
#     <scipp.VariableView>      float64    [dimensionless]  (x)  [0.000000, 0.000000]

# %%
d.masks['mask']
# Out:
#     <scipp.VariableView>      bool       [dimensionless]  (x)  [False, False]

# %%
d.attrs['info']
# Out:
#     <scipp.VariableView>      string     [dimensionless]  ()  ["text"]

# %% [markdown]
# ## Delete / remove a data item, a coord, labels, a mask, or an attr

# %%
del d['data']
del d.coords['x']
del d.coords['lab']
del d.masks['mask']
del d.attrs['info']
d
# Out:
# <scipp.Dataset>
# Dimensions: {}

# %% [markdown]
# ## Copy variables, data arrays, or dataset
#
# Note that **scipp always makes a deep copy**.
# This includes the case of storing native Python objects in a variable.

# %%
deep_copy = d.copy()         # Option 1
import copy
deep_copy = copy.copy(d)     # Option 2
deep_copy = copy.deepcopy(d) # Option 3

# %% [markdown]
# Again, note that all three options result in a deep copy.
# The syntax is the same for variables, data arrays, and datasets.

# %% [markdown]
# ## Create stand-alone objects from (slice) views
#
# Views created by slicing, or from selecting an item in a data reference data in the original container.
# Use `copy` to convert a view into a stand alone object:

# %%
deep_copy = var['x', 0:1].copy()
deep_copy = copy.copy(var['x', 0:1])

# %%
d['data'] = var
deep_copy = d['data'].copy()
deep_copy = copy.copy(d['data'])
