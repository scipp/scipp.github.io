# %% [markdown]
# # Event data
#
# Scipp can handle *event data*, a certain type of sparse data, i.e., data that cannot directly be represented as a multi-dimensional array.
# For applications that rely solely on dense arrays of data this section can safely be ignored.
#
# Scipp supports event data in shape of a multi-dimensional array of lists.
# This could, e.g., be used to store data from an array of sensors/detectors that are read out independently, with potentially widely varying frequency.
#
# Event data can be created using a special `dtype`, `event_list_float64`, `event_list_float32`, `event_list_int64`, and `event_list_int32`.
# Since here we are not dealing with a dense array we cannot set values for all `x` from a numpy array.
# The recommended approach is to slice out all dimensions.
# Then the remaining values (for a particluar "x" in this case) are a dense array with a list-like interface.
# Initially all lists are empty:

# %%
import numpy as np
import scipp as sc

var = sc.Variable(dims=['x'],
                  shape=[4],
                  dtype=sc.dtype.event_list_float64)
sc.show(var)
var
# Out:
# <svg width=40em viewBox="0 0 24 7.3"><g><text x="0.0" y="0.6"                     style="font-size:0.48px">                    dims=[x], shape=[4], unit=dimensionless, variances=False                    </text><g><title>values</title><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.0" height="1" x="1.0" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 5.3 l 0.3 -0.3 h 0.0 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 5.3 m 0.0 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.0" height="1" x="1.0" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 4.3 l 0.3 -0.3 h 0.0 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 4.3 m 0.0 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.0" height="1" x="1.0" y="3.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 3.3 l 0.3 -0.3 h 0.0 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 3.3 m 0.0 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.0" height="1" x="1.0" y="2.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 2.3 l 0.3 -0.3 h 0.0 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 2.3 m 0.0 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /></g><text x="0.892" y="4.3" text-anchor="middle"                     fill="#444444" style="font-size:0.36px"                     transform="rotate(-90, 0.892, 4.3)">x</text></g></svg>
#     <scipp.Variable>          event_list_float64  [dimensionless]  (x)  [[], [], [], []]

# %%
var['x', 0].values = np.arange(3)
var['x', 1].values.append(42)
var['x', 0].values.extend(np.ones(3))
var['x', 3].values = np.ones(6)
sc.show(var)
var
# Out:
# <svg width=40em viewBox="0 0 24 7.3"><g><text x="0.0" y="0.6"                     style="font-size:0.48px">                    dims=[x], shape=[4], unit=dimensionless, variances=False                    </text><g><title>values</title><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.0" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 5.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 5.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.3" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.3 5.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.3 5.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.6" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.6 5.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.6 5.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.9" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.9 5.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.9 5.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="2.2" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.2 5.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.2 5.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="2.5" y="5.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.5 5.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.5 5.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.0" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.0" height="1" x="1.0" y="3.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 3.3 l 0.3 -0.3 h 0.0 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 3.3 m 0.0 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.0" y="2.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 2.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.0 2.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.3" y="2.3"/> <path style="fill:#ffd633 ...
#     <scipp.Variable>          event_list_float64  [dimensionless]  (x)  [[0.000000, 1.000000, ..., 1.000000, 1.000000], [42.000000], [], [1.000000, 1.000000, ..., 1.000000, 1.000000]]

# %%
var['x', 0].values
# Out:
# event_list_float64[0, 1, 2, 1, 1, 1]

# %%
var['x', 1].values
# Out:
# event_list_float64[42]

# %%
var['x', 2].values
# Out:
# event_list_float64[]

# %% [markdown]
# Operations between variables or datasets broadcast dense data to lists:

# %%
scale = sc.Variable(dims=['x'], values=np.arange(2.0, 6))
var *= scale
var['x', 0].values
# Out:
# event_list_float64[0, 2, 4, 2, 2, 2]

# %%
var['x', 1].values
# Out:
# event_list_float64[126]

# %%
var['x', 2].values
# Out:
# event_list_float64[]

# %% [markdown]
# Event data in a data array can be associated with a corresponding event coordinate and event labels:

# %%
a = sc.DataArray(data=var, coords={
    'x': sc.Variable(['x'], values=np.arange(4.0)),
    'y': var})
var['x', 0].values = np.arange(7)
var['x', 3].values = np.ones(2)
sc.show(a)
a
# Out:
# <svg width=40em viewBox="-2.3 0 24 6.4"><g transform="translate(0,0)"><g><text x="0" y="0.6"                     style="font-size:0.6px"></text><title>dims=[x], shape=[4], unit=dimensionless, variances=False</title><g><title>values</title><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.1" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.4" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.4 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.4 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.7" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.7 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.7 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="2.0" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.0 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.0 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="2.3" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.3 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.3 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="2.6" y="4.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.6 4.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 2.6 4.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.1" y="3.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 3.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 3.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.0" height="1" x="1.1" y="2.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 2.3 l 0.3 -0.3 h 0.0 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 2.3 m 0.0 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.1" y="1.3"/> <path style="fill:#ffd633;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 1.3 l 0.3 -0.3 h 0.3 l -0.3 0.3 z" id="path1" /> <path style="fill:#cdac29;stroke:#000;stroke-width:0.05;stroke-linejoin:round" d="m 1.1 1.3 m 0.3 0 l 0.3 -0.3 v 1 l -0.3 0.3 z" id="path2" /><rect style="fill:#ffe680;fill-opacity:1;stroke:#000;stroke-width:0.05" id="rect" width="0.3" height="1" x="1.4" y="1.3"/> <path style="fill:#f ...
# <scipp.DataArray>
# Dimensions: {{x, 4}}
# Coordinates:
#     x                         float64    [dimensionless]  (x)  [0.000000, 1.000000, 2.000000, 3.000000]
#     y                         event_list_float64  [dimensionless]  (x)  [[0.000000, 2.000000, ..., 2.000000, 2.000000], [126.000000], [], [5.000000, 5.000000, ..., 5.000000, 5.000000]]
# Data:
#                               event_list_float64  [dimensionless]  (x)  [[0.000000, 2.000000, ..., 2.000000, 2.000000], [126.000000], [], [5.000000, 5.000000, ..., 5.000000, 5.000000]]

# %% [markdown]
# The lengths of the sublists between coordinate and values (and variances) must match.
# Scipp does not enforce this when modifying sublists, but *does* verify correctness in operations on variables or data arrays.
